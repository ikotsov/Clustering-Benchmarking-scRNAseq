# %%
import pandas as pd

df = pd.read_csv('../data/GSE36552/raw/GSE36552.metadata.bminty.txt.gz', sep='\t')

df.columns
# Out:
# Index(['Cell|Type'], dtype='str')

# %%
stages = df['Cell|Type'].str.split('|').str[1]

# Count how many unique biological stages
num_clusters = stages.nunique()
print(f"Ground truth clusters: {num_clusters}")

# How many cells are in each
print("\nBiological Cluster Breakdown:")
print(stages.value_counts())
# Out:
# Ground truth clusters: 8
#
# Biological Cluster Breakdown:
# Cell|Type
# hESC passage        34
# Late blastocyst     30
# 8-cell embryo       20
# Morulae             16
# 4-cell embryo       12
# 2-cell embryo        6
# Oocyte               3
# Zygote               3
# Name: count, dtype: int64
